# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import interpolate
from random import randint

# %%
x = []
y = []
# xi = []
# yi = []

for _ in range(1, 51):
    value = randint(100, 1000)/100.0
    x.append(value)
    value = randint(100, 1000)/100.0
    y.append(value)
# plt.plot(x, y, '-')

# new_arr_of_elsx = []
# new_arr_of_elsy = []
new_arr_of_elsx1 = []
new_arr_of_elsy2 = []
# plt.figure(figsize=(30,15))

plt.plot(x, y, 'o')

x1 = np.linspace(x[0], x[1], 100)
y1 = np.linspace(y[0], y[1], 100)
f = interpolate.interp1d(x1, y1, 'cubic')
plt.plot(x1, f(x1),'-')

x2 = np.linspace(x[1], x[2], 100)
y2 = np.linspace(y[1], y[2], 100)
f = interpolate.interp1d(x2, y2, 'cubic')
plt.plot(x2, f(x2),'-')

x3 = np.linspace(x[2], x[3], 100)
y3 = np.linspace(y[2], y[3], 100)
f = interpolate.interp1d(x3, y3, 'cubic')
plt.plot(x3, f(x3),'-')

x4 = np.linspace(x[3], x[4], 100)
y4 = np.linspace(y[3], y[4], 100)
f = interpolate.interp1d(x4, y4, 'cubic')
plt.plot(x4, f(x4),'-')

x5 = np.linspace(x[4], x[5], 100)
y5 = np.linspace(y[4], y[5], 100)
f = interpolate.interp1d(x5, y5, 'cubic')
plt.plot(x5, f(x5),'-')

x6 = np.linspace(x[5], x[6], 100)
y6 = np.linspace(y[5], y[6], 100)
f = interpolate.interp1d(x6, y6, 'cubic')
plt.plot(x6, f(x6),'-')

x7 = np.linspace(x[6], x[7], 100)
y7 = np.linspace(y[6], y[7], 100)
f = interpolate.interp1d(x7, y7, 'cubic')
plt.plot(x7, f(x7),'-')

x8 = np.linspace(x[7], x[8], 100)
y8 = np.linspace(y[7], y[8], 100)
f = interpolate.interp1d(x8, y8, 'cubic')
plt.plot(x8, f(x8),'-')

x9 = np.linspace(x[8], x[9], 100)
y9 = np.linspace(y[8], y[9], 100)
f = interpolate.interp1d(x9, y9, 'cubic')
plt.plot(x9, f(x9),'-')

x10 = np.linspace(x[9], x[10], 100)
y10 = np.linspace(y[9], y[10], 100)
f = interpolate.interp1d(x10, y10, 'cubic')
plt.plot(x10, f(x10),'-')

x11 = np.linspace(x[10], x[11], 100)
y11 = np.linspace(y[10], y[11], 100)
f = interpolate.interp1d(x11, y11, 'cubic')
plt.plot(x11, f(x11),'-')

x12 = np.linspace(x[11], x[12], 100)
y12 = np.linspace(y[11], y[12], 100)
f = interpolate.interp1d(x12, y12, 'cubic')
plt.plot(x12, f(x12),'-')

x13 = np.linspace(x[12], x[13], 100)
y13 = np.linspace(y[12], y[13], 100)
f = interpolate.interp1d(x13, y13, 'cubic')
plt.plot(x13, f(x13),'-')

x14 = np.linspace(x[13], x[14], 100)
y14 = np.linspace(y[13], y[14], 100)
f = interpolate.interp1d(x14, y14, 'cubic')
plt.plot(x14, f(x14),'-')

x15 = np.linspace(x[14], x[15], 100)
y15 = np.linspace(y[14], y[15], 100)
f = interpolate.interp1d(x15, y15, 'cubic')
plt.plot(x15, f(x15),'-')

x16 = np.linspace(x[15], x[16], 100)
y16 = np.linspace(y[15], y[16], 100)
f = interpolate.interp1d(x16, y16, 'cubic')
plt.plot(x16, f(x16),'-')

x17 = np.linspace(x[16], x[17], 100)
y17 = np.linspace(y[16], y[17], 100)
f = interpolate.interp1d(x17, y17, 'cubic')
plt.plot(x17, f(x17),'-')

x18 = np.linspace(x[17], x[18], 100)
y18 = np.linspace(y[17], y[18], 100)
f = interpolate.interp1d(x18, y18, 'cubic')
plt.plot(x18, f(x18),'-')

x19 = np.linspace(x[18], x[19], 100)
y19 = np.linspace(y[18], y[19], 100)
f = interpolate.interp1d(x19, y19, 'cubic')
plt.plot(x19, f(x19),'-')

x20 = np.linspace(x[19], x[20], 100)
y20 = np.linspace(y[19], y[20], 100)
f = interpolate.interp1d(x20, y20, 'cubic')
plt.plot(x20, f(x20),'-')

x21 = np.linspace(x[20], x[21], 100)
y21 = np.linspace(y[20], y[21], 100)
f = interpolate.interp1d(x21, y21, 'cubic')
plt.plot(x21, f(x21),'-')

x22 = np.linspace(x[21], x[22], 100)
y22 = np.linspace(y[21], y[22], 100)
f = interpolate.interp1d(x22, y22, 'cubic')
plt.plot(x22, f(x22),'-')

x23 = np.linspace(x[22], x[23], 100)
y23 = np.linspace(y[22], y[23], 100)
f = interpolate.interp1d(x23, y23, 'cubic')
plt.plot(x23, f(x23),'-')

x24 = np.linspace(x[23], x[24], 100)
y24 = np.linspace(y[23], y[24], 100)
f = interpolate.interp1d(x24, y24, 'cubic')
plt.plot(x24, f(x24),'-')

x25 = np.linspace(x[24], x[25], 100)
y25 = np.linspace(y[24], y[25], 100)
f = interpolate.interp1d(x25, y25, 'cubic')
plt.plot(x25, f(x25),'-')



x26 = np.linspace(x[25], x[26], 100)
y26 = np.linspace(y[25], y[26], 100)
f = interpolate.interp1d(x26, y26, 'cubic')
plt.plot(x26, f(x26),'-')

x27 = np.linspace(x[26], x[27], 100)
y27 = np.linspace(y[26], y[27], 100)
f = interpolate.interp1d(x27, y27, 'cubic')
plt.plot(x27, f(x27),'-')

x28 = np.linspace(x[27], x[28], 100)
y28 = np.linspace(y[27], y[28], 100)
f = interpolate.interp1d(x28, y28, 'cubic')
plt.plot(x28, f(x28),'-')

x29 = np.linspace(x[28], x[29], 100)
y29 = np.linspace(y[28], y[29], 100)
f = interpolate.interp1d(x29, y29, 'cubic')
plt.plot(x29, f(x29),'-')

x30 = np.linspace(x[29], x[30], 100)
y30 = np.linspace(y[29], y[30], 100)
f = interpolate.interp1d(x30, y30, 'cubic')
plt.plot(x30, f(x30),'-')

x31 = np.linspace(x[30], x[31], 100)
y31 = np.linspace(y[30], y[31], 100)
f = interpolate.interp1d(x31, y31, 'cubic')
plt.plot(x31, f(x31),'-')

x32 = np.linspace(x[31], x[32], 100)
y32 = np.linspace(y[31], y[32], 100)
f = interpolate.interp1d(x32, y32, 'cubic')
plt.plot(x32, f(x32),'-')

x33 = np.linspace(x[32], x[33], 100)
y33 = np.linspace(y[32], y[33], 100)
f = interpolate.interp1d(x33, y33, 'cubic')
plt.plot(x33, f(x33),'-')

x34 = np.linspace(x[33], x[34], 100)
y34 = np.linspace(y[33], y[34], 100)
f = interpolate.interp1d(x34, y34, 'cubic')
plt.plot(x34, f(x34),'-')

x35 = np.linspace(x[34], x[35], 100)
y35 = np.linspace(y[34], y[35], 100)
f = interpolate.interp1d(x35, y35, 'cubic')
plt.plot(x35, f(x35),'-')

x36 = np.linspace(x[35], x[36], 100)
y36 = np.linspace(y[35], y[36], 100)
f = interpolate.interp1d(x36, y36, 'cubic')
plt.plot(x36, f(x36),'-')

x37 = np.linspace(x[36], x[37], 100)
y37 = np.linspace(y[36], y[37], 100)
f = interpolate.interp1d(x37, y37, 'cubic')
plt.plot(x37, f(x37),'-')

x38 = np.linspace(x[37], x[38], 100)
y38 = np.linspace(y[37], y[38], 100)
f = interpolate.interp1d(x38, y38, 'cubic')
plt.plot(x38, f(x38),'-')

x39 = np.linspace(x[38], x[39], 100)
y39 = np.linspace(y[38], y[39], 100)
f = interpolate.interp1d(x39, y39, 'cubic')
plt.plot(x39, f(x39),'-')

x40 = np.linspace(x[39], x[40], 100)
y40 = np.linspace(y[39], y[40], 100)
f = interpolate.interp1d(x40, y40, 'cubic')
plt.plot(x40, f(x40),'-')

x41 = np.linspace(x[40], x[41], 100)
y41 = np.linspace(y[40], y[41], 100)
f = interpolate.interp1d(x41, y41, 'cubic')
plt.plot(x41, f(x41),'-')

x42 = np.linspace(x[41], x[42], 100)
y42 = np.linspace(y[41], y[42], 100)
f = interpolate.interp1d(x42, y42, 'cubic')
plt.plot(x42, f(x42),'-')

x43 = np.linspace(x[42], x[43], 100)
y43 = np.linspace(y[42], y[43], 100)
f = interpolate.interp1d(x43, y43, 'cubic')
plt.plot(x43, f(x43),'-')

x44 = np.linspace(x[43], x[44], 100)
y44 = np.linspace(y[43], y[44], 100)
f = interpolate.interp1d(x44, y44, 'cubic')
plt.plot(x44, f(x44),'-')

x45 = np.linspace(x[44], x[45], 100)
y45 = np.linspace(y[44], y[45], 100)
f = interpolate.interp1d(x45, y45, 'cubic')
plt.plot(x45, f(x45),'-')

x46 = np.linspace(x[45], x[46], 100)
y46 = np.linspace(y[45], y[46], 100)
f = interpolate.interp1d(x46, y46, 'cubic')
plt.plot(x46, f(x46),'-')

x47 = np.linspace(x[46], x[47], 100)
y47 = np.linspace(y[46], y[47], 100)
f = interpolate.interp1d(x47, y47, 'cubic')
plt.plot(x47, f(x47),'-')

x48 = np.linspace(x[47], x[48], 100)
y48 = np.linspace(y[47], y[48], 100)
f = interpolate.interp1d(x48, y48, 'cubic')
plt.plot(x48, f(x48),'-')

x49 = np.linspace(x[48], x[49], 100)
y49 = np.linspace(y[48], y[49], 100)
f = interpolate.interp1d(x49, y49, 'cubic')
plt.plot(x49, f(x49),'-')

# x50 = np.linspace(x[49], x[50], 100)
# y50 = np.linspace(y[49], y[50], 100)
# f = interpolate.interp1d(x50, y50, 'cubic')
# plt.plot(x50, f(x50),'-')

# plt.grid()
plt.show()
# plt.plot(x, y, 'o')
# plt.plot(x1, f(x1),'-')



# for i in range(1, 51):
#     x1 = np.linspace(x[i], x[i+1], 100)
#     y1 = np.linspace(y[i], y[i+1], 100)
#     f = interpolate.interp1d(x1, y1, 'cubic')
#     y2 = f(x1)
#     print(x1, '\n', y2)
#     new_arr_of_elsx1.append(x1)
#     new_arr_of_elsy2.append(y2)
# print(new_arr_of_elsx1, '\n', new_arr_of_elsy2)
    
# plt.plot(x, y, 'o')
# plt.plot(new_arr_of_elsx1, new_arr_of_elsy1, '-')
# plt.grid()
# plt.show()
# x1 = np.linspace(x[0], x[1], 100)
# y1 = np.linspace(y[0], y[1], 100)
# x2 = np.linspace(x[1], x[2], 100)
# y2 = np.linspace(y[1], y[2], 100)
# f = interpolate.interp1d(x1, y1, 'cubic')
# plt.figure(figsize=(30,15))
# plt.plot(x, y, 'o')
# plt.plot(x1, f(x1),'-')
# f = interpolate.interp1d(x2, y2, 'cubic')
# plt.plot(x2, f(x2), '-')
# plt.grid()
# plt.show()

# %%
# x = np.arange(0, 6, 1)
# y = np.cos(x)
# # plt.figure(figsize=(100,15))
# # xn = np.linspace(0, 5, 6)
# f = interpolate.interp1d(x, y, 'cubic')
# xn = np.linspace(0, 5, 100)
# yn = f(xn)
# plt.scatter(x, y)
# # plt.plot(x, y, 'o')
# plt.plot(xn, yn, '-')
# plt.show()

# %%
# for i in range(len(x)-1):
#     for j in range(len(x)-i-1):
#         if (x[j] > x[j+1]):
# #             x[j], x[j+1] = x[j+1], x[i]
#             #
#             temp = x[j]
#             x[j] = x[j+1]
#             x[j+1] = temp

#             temp = y[j]
#             y[j] = y[j+1]
#             y[j+1] = temp
# a = []
# b = []
# for i in range(0, 100):       
#     a = -1/2 * x[i] + (3/2*x[i+1]) - 3/2*x[i+2] + 1/2*x[i+3]*(X[i]**3) + x[i] - (5/2*x[i+1]) - 2*x[i+2] - 1/2*x[i+3]*(X[i]**2) + (-1/2*x[i]) + 1/2*x[i+2]*X[i] + x[i+1]
#     b = -1/2 * y[i] + (3/2*y[i+1]) - 3/2*y[i+2] + 1/2*y[i+3]*(X[i]**3) + y[i] - (5/2*y[i+1]) - 2*y[i+2] - 1/2*y[i+3]*(X[i]**2) + (-1/2*y[i]) + 1/2*y[i+2]*X[i] + y[i+1]


# x2 = x1
# y2 = y1

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import interpolate
from random import randint
x = []
y = []
xi = []
yi = []

for _ in range(1, 101):
    value = randint(100, 1000)/100.00
    x.append(value)
    value = randint(100, 1000)/100.00
    y.append(value)

plt.plo
# Out:
# [2.74, 9.03, 9.3, 9.17, 7.93, 5.97, 4.73, 6.51, 5.56, 3.33, 8.93, 5.67, 6.86, 1.29, 8.66, 5.54, 9.08, 3.8, 5.7, 6.02, 8.58, 8.45, 4.39, 2.42, 8.29, 9.4, 4.29, 5.54, 5.27, 3.37, 7.89, 4.02, 1.04, 5.89, 4.37, 2.45, 2.9, 5.92, 3.68, 5.78, 6.05, 3.6, 5.0, 2.88, 4.45, 8.7, 7.97, 2.16, 4.92, 9.84, 4.66, 2.4, 7.88, 7.65, 9.96, 2.52, 1.39, 7.7, 6.48, 9.4, 6.34, 3.21, 3.61, 8.16, 1.16, 7.61, 4.6, 9.3, 4.97, 5.17, 5.32, 9.7, 6.66, 7.59, 3.9, 6.69, 2.24, 1.56, 3.98, 4.88, 6.27, 9.32, 9.73, 1.12, 2.55, 3.23, 5.31, 1.45, 4.08, 2.76, 3.02, 8.86, 8.27, 7.34, 5.69, 4.18, 2.77, 9.47, 9.05, 3.09]
# ...

# %%
# x_parabola = np.array(x) # array for x
# y_parabola = np.array(y) # array for y
# plt.figure(figsize=(50,15))
# xn = np.linspace(x_parabola[0], x_parabola[-1], len(x_parabola)*100)
# f = interpolate.interp1d(x_parabola, y_parabola, 'cubic')
# yn = f(xn)
# plt.plot(x_parabola, y_parabola, 'o', xn, yn, '-')

# %%
# x = np.arange(0, 6, 0.01)
# y = np.cos(x)
# # plt.figure(figsize=(50,15))
# # xn = np.linspace(0, 5, 6)
# f = interpolate.interp1d(x, y, 'cubic')
# xn = np.linspace(0, 5, 1)
# yn = f(xn)
# plt.plot(x, y, 'o', xn, yn, '-')
# plt.show()

# %%
# print(x_parabola, '\n', y_parabola)
# plt.figure()
# u = plt.plot(x_parabola,y_parabola,'ro') # plot the points
# t = np.linspace(0, 1000, len(x_parabola)) # parameter t to parametrize x and y
# print(t)
# pxLagrange = scipy.interpolate.lagrange(t, x_parabola) # X(T)
# pyLagrange = scipy.interpolate.lagrange(t, y_parabola) # Y(T)
# n = 100
# ts = np.linspace(t[0],t[-1],n)
# xLagrange = pxLagrange(ts) # lagrange x coordinates
# yLagrange = pyLagrange(ts) # lagrange y coordinates
# plt.plot(xLagrange, yLagrange)
# plt.show()

# %%
# data = pd.read_csv('Book1.csv')

# # print(data.col_2)
# plt.grid()
# plt.plot(data.col_2)
# plt.show()

# list_of_randnumbers_for_x = []
# list_of_randnumbers_for_y = []
# for _ in range(1, 101):
#     i = randint(1, 100)
#     list_of_randnumbers_for_x.append(i)
    
# print("\n")
# step = 0
# for _ in range(1, 101):
#     i = randint(1 + step, 100)
#     step = step + 1
#     list_of_randnumbers_for_x.append(i)



# dict_of_els = {}


# x_temp = np.arange(1, 101)
# y_temp = list_of_randnumbers_for_y

# y = sorted(y_temp)
# x = np.array(x_temp).reshape((1, -1))
# print(x)
# print(y)
# xn = np.linspace(1, 100, 100)
# f = interpolate.interp1d(x, y, 'cubic')
# yn = f(xn)

plt.plot(list_of_randnumbers_for_y, 'o')
plt.show()

# print(x)
# print('\n')
# print(y)

# xn = np.linspace(x[0], x[-1], 1000, retstep=True)
# f = interpolate.interp1d(x, y, 'cubic')
# yn = f(xn)

# plt.figure(figsize=(50,15))
# plt.plot(x, y, 'o', xn, yn, '-')
# plt.show()

# x = np.arange(1, 8, 2)
# y = np.log(x**2) * x**2
# # print(x)
# f = interpolate.interp1d(x, y, 'cubic')
# xn = np.linspace(1, 7, 200)
# yn = f(xn)
# plt.figure(figsize=(50,15))
# plt.plot(x, y, 'o', xn, yn, '-')
# plt.grid()
# plt.show()

x = np.arange(0, 6, 0.1)
print(len(x))
print(x)
# y = np.linspace()
# y = np.cos(x)
# # plt.figure(figsize=(50,15))
# # xn = np.linspace(0, 5, 6)
# f = interpolate.interp1d(x, y, 'cubic')
# xn = np.linspace(0, 5, 1)
# yn = f(xn)
# plt.plot(x, y, 'o', xn, yn, '-')
# plt.show()

# f = interpolate.interp1d(list_of_randnumbers_for_x, list_of_randnumbers_for_y, kind=3)
# x1=np.linspace(list_of_randnumbers_for_x[0], list_of_randnumbers_for_x[-1], 50)
# plt.plot(x, y, 'o', x1, f(x1), '-')

# x = np.array([0, 20, 40, 60, 80, 100],float)
# y = np.array([26.0, 48.6, 61.6, 71.2, 74.8, 75.2],float)

# def cubic_interp(xp, y):
#     yp = 0
#     for xi, yi in zip(x,y):
#         p = np.prod((xp-x[x != xi])/(xi-x[x != xi]))
#         yp += yi*p
#     return yp

# xp = x;
# yn = cubic_interp(xp, y)
# plt.plot(x, y, 'o')
# plt.show()
